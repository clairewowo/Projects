# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# This is some data that I took from myself between late March and early May of 2023. I was curious what factors affected my sleep quality, but didn't end up analyzing the data for some time.
#
# Variables:
#
# Quality: my quality of sleep was noted after I woke up and is on a scale of 1 to 5, 5 being very good and 1 being bad. There are in between values, such as 3.5.
#
#
# Meditate: if I meditated before going to sleep
#
# Walk/run?: if I either went on a intentional 15+ minute walk or on a run that day. There is only one day where I didn't do either.
#
# Screen: if I looked at a screen at least 15 minutes before sleeping.
#
# Nap: if I took a nap earlier that day
#
# Tiredness: how tired I felt before sleeping, on a scale of 1 to 5. 5 = very tired, 1= energetic.
#
# Quality of day: how I rated my day on a scale of 1 to 5, 5 being very good and 1 being bad. This is a general indicator of how happy I was during the day.
#
# For both tiredness and quality of day, I didn't start recording them until later into my logging; that is why there are missing values.

# %%
sleep_df = pd.read_csv('Data/sleep-data.csv')
sleep_df
# Out:
#    night  Quality Time slept Time woken up Meditate? Walk/run? Screen? Nap?  \
# 0   3/26      2.0      11:20          6:50       yes      walk     yes   no
# 1   3/27      4.0      10:50          6:50       yes       run     yes   no
# 2   3/28      4.5      11:15          7:30        no      walk      no   no
# 3   3/29      3.0      11:00          6:50        no       run      no   no
# 4   3/30      3.0      12:00          7:25        no      walk     yes   no
# 5   3/31      4.0      11:05          8:30        no      walk      no   no
# 6    4/3      4.5      11:50          6:50       yes        no     yes   no
# 7    4/4      4.0      11:20          6:50        no       run      no   no
# 8    4/5      2.0      11:40          6:50        no       run      no   no
# 9    4/6      3.0      11:45          7:25       yes       run      no  yes
# 10   4/7      4.0      11:50          8:30       yes       run      no   no
# 11   4/8      4.0      11:50          8:30        no      walk      no   no
# 12   4/9      5.0      11:30          6:50        no       run      no   no
# 13  4/10      4.0      11:30          6:50        no      walk      no   no
# 14  4/11      3.0      11:20          6:50        no       run     yes  yes
# 15  4/12      3.0      11:50          6:50        no      walk     yes   no
# 16  4/13      4.0      11:00          6:30       yes       run     yes   no
# 17  4/15      4.0      12:00          8:30       yes       run     yes   no
# 18  4/16      4.5      11:30          8:00        no       run     yes   no
# 19  4/17      4.5      11:45          8:00        no      walk     yes   no
# 20  4/18      4.5      11:55          7:45        no       run      no   no
# 21  4/19      4.5      12:00          7:45        no      walk      no  yes
# 22  4/21      4.5      10:50          7:00        no      walk      no  yes
# 23  4/24      5.0      12:30          6:50        no      walk      no   no
# 24  4/25      2.0      12:00          6:50        no      walk     yes   no
# 25  4/26      2.0      11:30          6:50        no       run      no   no
# 26  4/30      3.0      11:00          6:15        no      walk      no   no
# 27   5/1      4.0      11:30          6:50        no       run      no   no
# 28   5/2      5.0      11:00          6:20        no       run      no   no
# 29   5/3      5.0      11:40          6:50        no      walk      no  yes
#
#     Tiredness before  Quality of day
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# 5                NaN             NaN
# 6                NaN             NaN
# 7                NaN             NaN
# 8                NaN             NaN
# 9                NaN             NaN
# 10               NaN             NaN
# 11               NaN             NaN
# 12               5.0             4.0
# 13               5.0             4.0
# 14               4.0             3.0
# 15               3.0             3.0
# 16               3.5             3.5
# 17               3.5             4.0
# 18               3.0             4.0
# 19               2.0             5.0
# 20               3.5             4.0
# 21               3.0             5.0
# 22               3.0             3.0
# 23               2.0             5.0
# 24               4.0             3.0
# 25               5.0             2.0
# 26               5.0             3.0
# 27               5.0             2.0
# 28               3.0             3.0
# 29               3.0             3.0

# %%
sleep_df = sleep_df.assign(Quality = sleep_df.get('Quality').apply(float))
sleep_df
# Out:
#    night  Quality Time slept Time woken up Meditate? Walk/run? Screen? Nap?  \
# 0   3/26      2.0      11:20          6:50       yes      walk     yes   no
# 1   3/27      4.0      10:50          6:50       yes       run     yes   no
# 2   3/28      4.5      11:15          7:30        no      walk      no   no
# 3   3/29      3.0      11:00          6:50        no       run      no   no
# 4   3/30      3.0      12:00          7:25        no      walk     yes   no
# 5   3/31      4.0      11:05          8:30        no      walk      no   no
# 6    4/3      4.5      11:50          6:50       yes        no     yes   no
# 7    4/4      4.0      11:20          6:50        no       run      no   no
# 8    4/5      2.0      11:40          6:50        no       run      no   no
# 9    4/6      3.0      11:45          7:25       yes       run      no  yes
# 10   4/7      4.0      11:50          8:30       yes       run      no   no
# 11   4/8      4.0      11:50          8:30        no      walk      no   no
# 12   4/9      5.0      11:30          6:50        no       run      no   no
# 13  4/10      4.0      11:30          6:50        no      walk      no   no
# 14  4/11      3.0      11:20          6:50        no       run     yes  yes
# 15  4/12      3.0      11:50          6:50        no      walk     yes   no
# 16  4/13      4.0      11:00          6:30       yes       run     yes   no
# 17  4/15      4.0      12:00          8:30       yes       run     yes   no
# 18  4/16      4.5      11:30          8:00        no       run     yes   no
# 19  4/17      4.5      11:45          8:00        no      walk     yes   no
# 20  4/18      4.5      11:55          7:45        no       run      no   no
# 21  4/19      4.5      12:00          7:45        no      walk      no  yes
# 22  4/21      4.5      10:50          7:00        no      walk      no  yes
# 23  4/24      5.0      12:30          6:50        no      walk      no   no
# 24  4/25      2.0      12:00          6:50        no      walk     yes   no
# 25  4/26      2.0      11:30          6:50        no       run      no   no
# 26  4/30      3.0      11:00          6:15        no      walk      no   no
# 27   5/1      4.0      11:30          6:50        no       run      no   no
# 28   5/2      5.0      11:00          6:20        no       run      no   no
# 29   5/3      5.0      11:40          6:50        no      walk      no  yes
#
#     Tiredness before  Quality of day
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# 5                NaN             NaN
# 6                NaN             NaN
# 7                NaN             NaN
# 8                NaN             NaN
# 9                NaN             NaN
# 10               NaN             NaN
# 11               NaN             NaN
# 12               5.0             4.0
# 13               5.0             4.0
# 14               4.0             3.0
# 15               3.0             3.0
# 16               3.5             3.5
# 17               3.5             4.0
# 18               3.0             4.0
# 19               2.0             5.0
# 20               3.5             4.0
# 21               3.0             5.0
# 22               3.0             3.0
# 23               2.0             5.0
# 24               4.0             3.0
# 25               5.0             2.0
# 26               5.0             3.0
# 27               5.0             2.0
# 28               3.0             3.0
# 29               3.0             3.0

# %%
sleep_df.groupby('Meditate?').mean()
# Out:
# /var/folders/r6/j2xslqfj0lg0bxy1nj8b6fzm0000gn/T/ipykernel_87152/3079724759.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sleep_df.groupby('Meditate?').mean()
#             Quality  Tiredness before  Quality of day
# Meditate?
# no         3.826087           3.65625            3.50
# yes        3.642857           3.50000            3.75

# %%
def time_between(sleep, wake):
    
    times = np.array([])
    wake_list = wake.split(':')
    wake_list[0] = int(wake_list[0]) + 12
    wake_list[1] = int(wake_list[1])
    wake_list = np.array(wake_list)
    
    sleep_list = sleep.split(':')
    sleep_list[0] = int(sleep_list[0])
    sleep_list[1] = int(sleep_list[1])
    sleep_list = np.array(sleep_list)

    time = wake_list - sleep_list
    
    return time[0] + time[1] / 60

# %%
print(time_between('11:20', '8:00'))
# Out:
# 8.666666666666666

# %%
times_sleep = np.array(sleep_df.get('Time slept'))
times_wake = np.array(sleep_df.get('Time woken up'))


total_times = []
for i in range(len(times_sleep)):
    sleep = times_sleep[i]
    wake = times_wake[i]
    time = time_between(sleep, wake)
    total_times.append(time)

sleep_df = sleep_df.assign(total_time_slept = total_times)

# %%
sleep_df
# Out:
#    night  Quality Time slept Time woken up Meditate? Walk/run? Screen? Nap?  \
# 0   3/26      2.0      11:20          6:50       yes      walk     yes   no
# 1   3/27      4.0      10:50          6:50       yes       run     yes   no
# 2   3/28      4.5      11:15          7:30        no      walk      no   no
# 3   3/29      3.0      11:00          6:50        no       run      no   no
# 4   3/30      3.0      12:00          7:25        no      walk     yes   no
# 5   3/31      4.0      11:05          8:30        no      walk      no   no
# 6    4/3      4.5      11:50          6:50       yes        no     yes   no
# 7    4/4      4.0      11:20          6:50        no       run      no   no
# 8    4/5      2.0      11:40          6:50        no       run      no   no
# 9    4/6      3.0      11:45          7:25       yes       run      no  yes
# 10   4/7      4.0      11:50          8:30       yes       run      no   no
# 11   4/8      4.0      11:50          8:30        no      walk      no   no
# 12   4/9      5.0      11:30          6:50        no       run      no   no
# 13  4/10      4.0      11:30          6:50        no      walk      no   no
# 14  4/11      3.0      11:20          6:50        no       run     yes  yes
# 15  4/12      3.0      11:50          6:50        no      walk     yes   no
# 16  4/13      4.0      11:00          6:30       yes       run     yes   no
# 17  4/15      4.0      12:00          8:30       yes       run     yes   no
# 18  4/16      4.5      11:30          8:00        no       run     yes   no
# 19  4/17      4.5      11:45          8:00        no      walk     yes   no
# 20  4/18      4.5      11:55          7:45        no       run      no   no
# 21  4/19      4.5      12:00          7:45        no      walk      no  yes
# 22  4/21      4.5      10:50          7:00        no      walk      no  yes
# 23  4/24      5.0      12:30          6:50        no      walk      no   no
# 24  4/25      2.0      12:00          6:50        no      walk     yes   no
# 25  4/26      2.0      11:30          6:50        no       run      no   no
# 26  4/30      3.0      11:00          6:15        no      walk      no   no
# 27   5/1      4.0      11:30          6:50        no       run      no   no
# 28   5/2      5.0      11:00          6:20        no       run      no   no
# 29   5/3      5.0      11:40          6:50        no      walk      no  yes
#
#     Tiredness before  Quality of day  total_time_slept
# 0                NaN             NaN          7.500000
# 1                NaN             NaN          8.000000
# 2                NaN             NaN          8.250000
# 3                NaN             NaN          7.833333
# 4                NaN             NaN          7.416667
# 5                NaN             NaN          9.416667
# 6                NaN             NaN          7.000000
# 7                NaN             NaN          7.500000
# 8                NaN             NaN          7.166667
# 9                NaN             NaN          7.666667
# 10               NaN             NaN          8.666667
# 11               NaN             NaN          8.666667
# 12               5.0             4.0          7.333333
# 13               5.0             4.0          7.333333
# 14               4.0             3.0          7.500000
# 15               3.0             3.0          7.000000
# 16               3.5             3.5          7.500000
# 17               3.5             4.0          8.500000
# 18               3.0             4.0          8.500000
# 19               2.0             5.0          8.250000
# 20               3.5             4.0          7.833333
# 21               3.0             5.0          7.750000
# 22               3.0             3.0          8.166667
# 23               2.0             5.0          6.333333
# 24               4.0             3.0          6.833333
# 25               5.0             2.0          7.333333
# 26               5.0             3.0          7.250000
# 27               5.0             2.0          7.333333
# 28               3.0             3.0          7.333333
# 29               3.0             3.0          7.166667

# %%
sleep_df.plot.scatter(x='total_time_slept', y='Quality');

# %% [markdown]
# When I eyeball, there seems to be no correlation. But if I remove the outlier point at 6.3 hours of sleep, there could be a positive correlation with time slept and quality. I'll remove the outlier point and see if there is correlation. There is another problem, which is that quality of sleep was not a continuous variable when I rated it on a scale of 1 to 5.

# %%
sleep_no_outlier = sleep_df.drop(index = 23)

# %%
sleep_no_outlier.plot.scatter(x = 'total_time_slept', y='Quality');

# %%
def standardize(values):
    m = values.mean()
    return (values - m) / np.std(values)

# %%
def calculate_r(df, x, y):
    standard_x = standardize(df.get(x))
    standard_y = standardize(df.get(y))
    return (standard_x * standard_y).mean()

# %%
r = calculate_r(sleep_no_outlier, 'total_time_slept', 'Quality')

# %%
mean_time = sleep_no_outlier.get('total_time_slept').mean()
sd_time = np.std(sleep_no_outlier.get('total_time_slept'))
mean_y = sleep_no_outlier.get('Quality').mean()
sd_y = np.std(sleep_no_outlier.get('Quality'))
def predict(time_slept):
    y_su = r * (time_slept - mean_time) / sd_time
    return y_su * sd_y + mean_y

# %%
predictions = sleep_no_outlier.assign(predicted_quality = sleep_no_outlier.get('total_time_slept').apply(predict))
ax = predictions.plot(kind='scatter', x='total_time_slept', y='Quality', figsize=(10, 5))

predictions.plot(kind='line', x='total_time_slept', y='predicted_quality', ax = ax, color='orange', \
                 label='regression line', lw=4);

# %% [markdown]
# So, there is a weak positive association with time slept and quality of sleep

# %%
sleep_df.groupby('Screen?').mean()
# Out:
# /var/folders/r6/j2xslqfj0lg0bxy1nj8b6fzm0000gn/T/ipykernel_87152/2853563726.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sleep_df.groupby('Screen?').mean()
#           Quality  Tiredness before  Quality of day  total_time_slept
# Screen?
# no       3.947368          3.863636        3.454545          7.701754
# yes      3.500000          3.285714        3.642857          7.636364

# %%
sleep_df.groupby('Nap?').mean()
# Out:
# /var/folders/r6/j2xslqfj0lg0bxy1nj8b6fzm0000gn/T/ipykernel_87152/123504302.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sleep_df.groupby('Nap?').mean()
#       Quality  Tiredness before  Quality of day  total_time_slept
# Nap?
# no       3.74              3.75        3.535714          7.683333
# yes      4.00              3.25        3.500000          7.650000

# %% [markdown]
# ## Looking at screens and sleep quality: permutation test
#
# Based on the data above, looking at a screen right before sleeping is correlated with worse sleep quality. But is it statistically significant?
#
# Null hypothesis: taking a nap during the day is not correlated with quality of sleep
#
# Alternative hypothesis: taking a nap during the day is correlated with a higher quality of sleep at night
#
# Note: Like all studies, I cannot find causation, only correlation. There could be a chance that looking at a screen is correlated with another variable that is the real cause for better sleep
#
#
# I will do a permutation test

# %%
def difference_screen(df):
    means = df.get(['shuffled_screen', 'Quality']).groupby('shuffled_screen').mean().get('Quality')
    return means.loc['yes'] - means.loc['no']

# %%
differences = np.array([])
for i in np.arange(500):
    shuffled = np.random.permutation(sleep_df.get('Screen?'))
    shuffled_df = sleep_df.assign(shuffled_screen = shuffled)
    diff = difference_screen(shuffled_df)
    differences = np.append(differences, diff)
pd.DataFrame().assign(difference_quality = differences).plot(kind = 'hist', ec = 'w', figsize = (6, 3));

# %%
grouped = sleep_df.get(['Quality', 'Screen?']).groupby('Screen?').mean()
observed_diff = float(grouped.loc['no'] - grouped.loc['yes'])
observed_diff
# Out:
# 0.4473684210526314

# %%
np.count_nonzero(differences >= observed_diff) / len(differences)
# Out:
# 0.114

# %% [markdown]
# The p value is too high for it to be statistically significant.

# %% [markdown]
# ## How early I sleep and how it affects sleep quality: linear regression
# Let's investigate another variable: if sleeping early results in better quality sleep. I first have to quantify the time slept, so I'll convert the values into minutes after 10 pm. I'll also just create a data frame with only when I slept and quality of sleep, to make things simpler.

# %%
def min_after_10(time):
    split_time = time.split(':')
    split_time[0] = int(split_time[0])
    split_time[1] = int(split_time[1])
    return (split_time[0] - 10) * 60 + split_time[1]

new_df = pd.DataFrame().assign(time_slept = sleep_df.get('Time slept').apply(min_after_10))
new_df = new_df.assign(quality = sleep_df.get('Quality'))
new_df
# Out:
#     time_slept  quality
# 0           80      2.0
# 1           50      4.0
# 2           75      4.5
# 3           60      3.0
# 4          120      3.0
# 5           65      4.0
# 6          110      4.5
# 7           80      4.0
# 8          100      2.0
# 9          105      3.0
# 10         110      4.0
# 11         110      4.0
# 12          90      5.0
# 13          90      4.0
# 14          80      3.0
# 15         110      3.0
# 16          60      4.0
# 17         120      4.0
# 18          90      4.5
# 19         105      4.5
# 20         115      4.5
# 21         120      4.5
# 22          50      4.5
# 23         150      5.0
# 24         120      2.0
# 25          90      2.0
# 26          60      3.0
# 27          90      4.0
# 28          60      5.0
# 29         100      5.0

# %%
new_df.plot(kind = 'scatter', x='time_slept', y='quality')
# Out:
# <Axes: xlabel='time_slept', ylabel='quality'>

# %% [markdown]
# There seems to be no correlation between how early I sleep and the quality of sleep I get.
# But what about how tired I feel before I sleep and my quality of day? Unfortunately, I only started recording these halfway through my spreadsheet, so the sample size is small, about 18 days.

# %% [markdown]
# ## Quality of day v. quality of sleep: linear regression

# %%
quality_day_df = sleep_df.iloc[12:29 + 1].reset_index()
quality_day_df
# Out:
#     index night  Quality Time slept Time woken up Meditate? Walk/run? Screen?  \
# 0      12   4/9      5.0      11:30          6:50        no       run      no
# 1      13  4/10      4.0      11:30          6:50        no      walk      no
# 2      14  4/11      3.0      11:20          6:50        no       run     yes
# 3      15  4/12      3.0      11:50          6:50        no      walk     yes
# 4      16  4/13      4.0      11:00          6:30       yes       run     yes
# 5      17  4/15      4.0      12:00          8:30       yes       run     yes
# 6      18  4/16      4.5      11:30          8:00        no       run     yes
# 7      19  4/17      4.5      11:45          8:00        no      walk     yes
# 8      20  4/18      4.5      11:55          7:45        no       run      no
# 9      21  4/19      4.5      12:00          7:45        no      walk      no
# 10     22  4/21      4.5      10:50          7:00        no      walk      no
# 11     23  4/24      5.0      12:30          6:50        no      walk      no
# 12     24  4/25      2.0      12:00          6:50        no      walk     yes
# 13     25  4/26      2.0      11:30          6:50        no       run      no
# 14     26  4/30      3.0      11:00          6:15        no      walk      no
# 15     27   5/1      4.0      11:30          6:50        no       run      no
# 16     28   5/2      5.0      11:00          6:20        no       run      no
# 17     29   5/3      5.0      11:40          6:50        no      walk      no
#
#    Nap?  Tiredness before  Quality of day  total_time_slept
# 0    no               5.0             4.0          7.333333
# 1    no               5.0             4.0          7.333333
# 2   yes               4.0             3.0          7.500000
# 3    no               3.0             3.0          7.000000
# 4    no               3.5             3.5          7.500000
# 5    no               3.5             4.0          8.500000
# 6    no               3.0             4.0          8.500000
# 7    no               2.0             5.0          8.250000
# 8    no               3.5             4.0          7.833333
# 9   yes               3.0             5.0          7.750000
# 10  yes               3.0             3.0          8.166667
# 11   no               2.0             5.0          6.333333
# 12   no               4.0             3.0          6.833333
# 13   no               5.0             2.0          7.333333
# 14   no               5.0             3.0          7.250000
# 15   no               5.0             2.0          7.333333
# 16   no               3.0             3.0          7.333333
# 17  yes               3.0             3.0          7.166667

# %%
quality_day_df.plot(kind = 'scatter', x='Quality of day', y='Quality');
# Out:
# <Axes: xlabel='Quality of day', ylabel='Quality'>

# %% [markdown]
# There seems to be a positive correlation that's relatively strong. What is r?

# %%
print(calculate_r(quality_day_df, 'Quality of day', 'Quality'))
# Out:
# 0.5435603598113905

# %% [markdown]
# What about how tired I am before I sleep?

# %%
tired_df = (sleep_df.iloc[12:29 + 1].reset_index().assign(tired = sleep_df.get('Tiredness before'))
            .assign(quality = sleep_df.get('Quality')))
tired_df.plot(kind = 'scatter', x= 'Tiredness before', y = 'Quality')
# Out:
# <Axes: xlabel='Tiredness before', ylabel='Quality'>

# %% [markdown]
# Maybe a very weak negative correlation??
